# %%
import pandas as pd

dummy_file = 'GDP time series'
DummyDummy = pd.read_excel(dummy_file)
DummyDummy.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-0bc30b27d69e> in <module>
#       2
#       3 dummy_file = 'GDP time series'
# ----> 4 DummyDummy = pd.read_excel(dummy_file)
#       5 DummyDummy.head()
#
# //anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# //anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ...

# %%
import pandas as pd
master_file = 'Master_File.xlsx'
Homeless = pd.read_excel(master_file)
Homeless.head()
# Out:
#                                           Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                                                NaN        NaN        NaN
# 1  Local Authority Homelessness Statistics (England)        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3                          Select a local authority:        NaN        NaN
# 4                                               Adur        NaN        NaN
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  Unnamed: 7 Unnamed: 8  \
# 0         NaN        NaN        NaN        NaN         NaN        NaN
# 1         NaN        NaN        NaN        NaN         NaN        NaN
# 2         NaN        NaN        NaN        NaN         NaN        NaN
# 3         NaN        NaN        NaN        NaN         NaN        NaN
# 4         NaN        NaN        NaN        NaN         NaN        NaN
#
#   Unnamed: 9 Unnamed: 10  Unnamed: 11
# 0        NaN         NaN          NaN
# ...
